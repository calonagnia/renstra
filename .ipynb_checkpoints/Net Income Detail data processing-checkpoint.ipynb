# %%
import os
import pandas as pd
import gspread
from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
import datetime  # Imported module to fix the datetime.datetime error

def main():
    path_realisasi = r"D:\Renstra\Full Month.xlsx"
    path_rkap = r"D:\Renstra\RKAP 25.xlsx"
    df = extract_excel(path_realisasi, "2026", 0)
    print(df.info())
    
    df_target = extract_excel(path_rkap, "Sheet1", 0)
    df_target = df_target[df_target["TAHUN"] == 2026]
    print(df_target.info())
    
        
def setting_header():
    
    print("a")
    
    
def extract_excel(path, sheet, chosen_header):
    # Added engine='calamine'
    df = pd.read_excel(path, sheet_name=sheet, header=chosen_header, engine='calamine')
    print(df.head(12))
    return df

def create_grouped_dfs(df):
    df_area = df.groupby(['AREA AP', 'province_desc'], as_index=False).agg({
        'revenue_column_name': 'sum',   
        'jml_spj': 'sum'               
    })
    
    # 2. Group by District (include Province)
    # Replace 'district_column_name' with your actual district column name
    df_province = df.groupby(['province_desc', 'district_column_name'], as_index=False).agg({
        'revenue_column_name': 'sum',   # <-- Replace with your actual revenue column name
        'jml_spj': 'sum'                
    })
    
    return df_area, df_province

#Nggak dipakai
def convert_xlsx_to_csv(excel_path, csv_path, sheet_name):
    print("Reading Excel file... (this may take a few seconds)")
    df = pd.read_excel(excel_path, sheet_name=sheet_name, engine='calamine')
    df.to_csv(csv_path, index=False)
    print(f"Success! Saved to: {csv_path}")   
    
if __name__ == '__main__':
    main()
# Out:
#       SEGMEN AREA AP  tahun  bulan    tanggal  regional regional_update  \
# 0   CORSALES  AREA 1   2026      1 2026-01-01  CORSALES        CORSALES
# 1   CORSALES  AREA 1   2026      1 2026-01-01  CORSALES        CORSALES
# 2   CORSALES  AREA 1   2026      1 2026-01-01  CORSALES        CORSALES
# 3   CORSALES  AREA 1   2026      1 2026-01-01  CORSALES        CORSALES
# 4   CORSALES  AREA 1   2026      1 2026-01-01  CORSALES        CORSALES
# 5   CORSALES  AREA 1   2026      1 2026-01-01  CORSALES        CORSALES
# 6   CORSALES  AREA 1   2026      1 2026-01-01  CORSALES        CORSALES
# 7   CORSALES  AREA 1   2026      1 2026-01-01  CORSALES        CORSALES
# 8   CORSALES  AREA 1   2026      1 2026-01-01  CORSALES        CORSALES
# 9   CORSALES  AREA 1   2026      1 2026-01-01  CORSALES        CORSALES
# 10  CORSALES  AREA 1   2026      1 2026-01-01  CORSALES        CORSALES
# 11  CORSALES  AREA 1   2026      1 2026-01-01  CORSALES        CORSALES
#
#    opco_area  province_code   province_desc  ...  order_reason sales_org  \
# 0   CORSALES           1010            ACEH  ...           NaN      7900
# 1   CORSALES           1011  SUMATERA UTARA  ...           NaN      7900
# 2   CORSALES           1011  SUMATERA UTARA  ...           NaN      7900
# 3   CORSALES           1011  SUMATERA UTARA  ...           NaN      7900
# 4   CORSALES           1011  SUMATERA UTARA  ...           NaN      7900
# 5   CORSALES           1011  SUMATERA UTARA  ...           NaN      7900
# 6   CORSALES           1012  SUMATERA BARAT  ...           NaN      7900
# 7   CORSALES           1012  SUMATERA BARAT  ...           NaN      7900
# 8   CORSALES           1012  SUMATERA BARAT  ...           NaN      7900
# 9   CORSALES           1013    RIAU DARATAN  ...           NaN      7900
# 10  CORSALES           1013    RIAU DARATAN  ...           NaN      7900
# 11  CORSALES           1013    RIAU DARATAN  ...           NaN      7900
#
#    opco_pemilik_brand opco_produsen jml_spj sched_dlvr_date request_dlvr_date  \
# 0                3000           SBA       1         46018.0           46018.0
# 1                3000           SBA       4         46001.0           46001.0
# 2                3000           SBA       4         46015.0           46015.0
# 3                3000           SBA       8         46006.0           46006.0
# 4                3000           SBA       8         46010.0           46010.0
# 5                3000           SBA       3         46020.0           46021.0
# 6                3000          3000       1         46021.0           46021.0
# 7                3000          3000       1         46023.0           46023.0
# 8                3000          3000       1         46023.0           46023.0
# 9                3000          3000       2         46021.0           46021.0
# 10               3000          3000       1         46023.0           46023.0
# 11               3000          3000       1         46023.0           46023.0
#
#      route  price_list royalti
# 0   ZR0003         6.0     NaN
# 1   ZR0002         1.0     NaN
# 2   ZR0002         1.0     NaN
# 3   ZR0002         1.0     NaN
# 4   ZR0002         1.0     NaN
# 5   ZR0002         1.0     NaN
# 6   ZR0003         6.0     NaN
# 7   ZR0003         6.0     NaN
# 8   ZR0003         6.0     NaN
# 9   ZR0003         6.0     NaN
# 10  ZR0003         6.0     NaN
# 11  ZR0003         6.0     NaN
#
# [12 rows x 49 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 304867 entries, 0 to 304866
# Data columns (total 49 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   SEGMEN               304867 non-null  object
#  1   AREA AP              304867 non-null  object
#  2   tahun                304867 non-null  int64
#  3   bulan                304867 non-null  int64
#  4   tanggal              304867 non-null  datetime64[ns]
#  5   regional             304867 non-null  object
#  6   regional_update      304867 non-null  object
#  7   opco_area            304842 non-null  object
#  8   province_code        304867 non-null  int64
#  9   province_desc        304867 non-null  object
#  10  district_code        304867 non-null  int64
#  11  district_desc        304867 non-null  object
#  12  brand                304866 non-null  object
#  13  material_code        304867 non-null  object
#  14  material_desc        304867 non-null  object
#  15  delivery_type        304867 non-null  object
#  16  baseunit_of_measure  304867 non-null  object
#  17  cekvolume            300981 non-null  object
#  18  shipto               304867 non-null  int64
#  19  shipto_desc          304867 non-null  object
#  20  soldto               304867 non-null  int64
#  21  soldto_desc          304867 non-null  object
#  22  plant                304867 non-null  object
#  23  plant_name           304867 non-null  object
#  24  area_name            304842 non-null  object
#  25  segment              304288 non-null  object
#  26  segment_material     304862 non-null  object
#  27  quantity             304867 non-null  float64
#  28  revenue              304867 non-null  float64
#  29  source               304867 non-null  object
#  30  tanggal_refresh      304867 non-null  object
#  31  so_no                304867 non-null  int64
#  32  reff_incoterm1       304867 non-null  object
#  33  reff_incoterm2       304867 non-null  object
#  34  incoterm             304867 non-null  object
#  35  incoterm_1           304867 non-null  object
#  36  incoterm_2           304867 non-null  object
#  37  incoterm_3           304867 non-null  object
#  38  cek_incoterm         304867 non-null  object
#  39  order_reason         660 non-null     object
#  40  sales_org            304867 non-null  object
#  41  opco_pemilik_brand   304867 non-null  object
#  42  opco_produsen        304867 non-null  object
#  43  jml_spj              304867 non-null  int64
#  44  sched_dlvr_date      301268 non-null  float64
#  45  request_dlvr_date    301268 non-null  float64
#  46  route                301268 non-null  object
#  47  price_list           301330 non-null  float64
#  48  royalti              69187 non-null   object
# dtypes: datetime64[ns](1), float64(5), int64(8), object(35)
# memory usage: 114.0+ MB
# None
#     KODE PROV PROVINSI KEMASAN KEMASAN DETIL  KODE DISTRIK    SALES DISTRICT  \
# 0        1010     ACEH   CURAH         CURAH        101001   KAB. ACEH BARAT
# 1        1010     ACEH   CURAH         CURAH        101001   KAB. ACEH BARAT
# 2        1010     ACEH   JUMBO   JUMBO 1 TON        101001   KAB. ACEH BARAT
# 3        1010     ACEH   CURAH         CURAH        101002   KAB. ACEH BESAR
# 4        1010     ACEH   CURAH         CURAH        101002   KAB. ACEH BESAR
# 5        1010     ACEH   CURAH         CURAH        101002   KAB. ACEH BESAR
# 6        1010     ACEH   CURAH         CURAH        101002   KAB. ACEH BESAR
# 7        1010     ACEH   CURAH         CURAH        101005  KAB. ACEH TENGAH
# 8        1010     ACEH   CURAH         CURAH        101005  KAB. ACEH TENGAH
# 9        1010     ACEH   CURAH         CURAH        101005  KAB. ACEH TENGAH
# 10       1010     ACEH   JUMBO   JUMBO 1 TON        101005  KAB. ACEH TENGAH
# 11       1010     ACEH   JUMBO   JUMBO 1 TON        101005  KAB. ACEH TENGAH
#
#    PRODUCTION PLANT KODE PLANT     DELIVERING PLANT KODE MATERIAL  ...  \
# 0       CP Indarung       7917   PP ACEH MALAHAYATI  121-302-0040  ...
# 1    CP Lhoknga SBA       79B9       CP Lhoknga SBA  121-302-0010  ...
# 2    CP Lhoknga SBA       79B9       CP Lhoknga SBA  121-301-0010  ...
# 3       CP Indarung       7917   PP Aceh Malahayati  121-302-0040  ...
# 4    CP Lhoknga SBA       79B9       CP Lhoknga SBA  121-302-0010  ...
# 5    CP Lhoknga SBA       79B9       CP Lhoknga SBA  121-302-0010  ...
# 6    CP Lhoknga SBA       79B9       CP Lhoknga SBA  121-302-0010  ...
# 7       CP Indarung       7918  PP ACEH LHOKSEUMAWE  121-302-0040  ...
# 8    CP Lhoknga SBA       79B7   PP Lhokseumawe SBA  121-302-0040  ...
# 9       CP Indarung       7918  PP ACEH LHOKSEUMAWE  121-302-0040  ...
# 10      CP Indarung       7917   PP Aceh Malahayati  121-301-0140  ...
# 11   CP Lhoknga SBA       79B9       CP Lhoknga SBA  121-301-0010  ...
#
#    Company Code       OA Old      AREA MATERIAL.1 CODE AREA COMPANY DESC  \
# 0          3000       0.0000  CORSALES      Curah       100           SP
# 1          3000       0.0000  CORSALES      Curah       100           SP
# 2             0       0.0000  CORSALES      Curah       100          SBI
# 3          3000       0.0000  CORSALES      Curah       100           SP
# 4             0       0.0000  CORSALES      Curah       100          SBI
# 5          3000       0.0000  CORSALES      Curah       100           SP
# 6          3000  337104.7968  CORSALES      Curah       100           SP
# 7             0       0.0000  CORSALES      Curah       100          SBI
# 8             0       0.0000  CORSALES      Curah       100          SBI
# 9          3000       0.0000  CORSALES      Curah       100           SP
# 10         3000       0.0000  CORSALES      Curah       100           SP
# 11            0       0.0000  CORSALES      Curah       100          SBI
#
#    TAHUN AREA AP CODE AREA AP   SEGMENT
# 0   2025  AREA 1          101  CORSALES
# 1   2025  AREA 1          101  CORSALES
# 2   2025  AREA 1          101  CORSALES
# 3   2025  AREA 1          101  CORSALES
# 4   2025  AREA 1          101  CORSALES
# 5   2025  AREA 1          101  CORSALES
# 6   2025  AREA 1          101  CORSALES
# 7   2025  AREA 1          101  CORSALES
# 8   2025  AREA 1          101  CORSALES
# 9   2025  AREA 1          101  CORSALES
# 10  2025  AREA 1          101  CORSALES
# 11  2025  AREA 1          101  CORSALES
#
# [12 rows x 185 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9018 entries, 0 to 9017
# Columns: 185 entries, KODE PROV to SEGMENT
# dtypes: float64(146), int64(6), object(33)
# memory usage: 12.7+ MB
# None
