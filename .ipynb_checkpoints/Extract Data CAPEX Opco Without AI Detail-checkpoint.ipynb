# %%
import os
import pandas as pd
import gspread
from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
import datetime  # Imported module to fix the datetime.datetime error

def connect_to_sheet():
    SCOPES = ['https://www.googleapis.com/auth/spreadsheets']
    creds = None
    if os.path.exists(r'C:\Users\mochamad.ilmawan\token.json'):
        creds = Credentials.from_authorized_user_file(r'C:\Users\mochamad.ilmawan\token.json', SCOPES)
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                r'D:\OneDrive\Documents\Direct Selling\MONITORING\Monitoring 2023\client_secret_738271294618-6g8e0hle4jpq8nau1d7b3q9jfsgp0ruk.apps.googleusercontent.com.json', SCOPES)
            creds = flow.run_local_server(port=0)
        with open(r'C:\Users\mochamad.ilmawan\token.json', 'w') as token:
            token.write(creds.to_json())
    return creds

def update_sheet(spreadsheetId, spread_range, scopes, creds, df):
    df_clean = df.copy()
    for col in df_clean.columns:
        if pd.api.types.is_datetime64_any_dtype(df_clean[col]):
            df_clean[col] = df_clean[col].dt.strftime('%Y-%m-%d')
            
    df_clean = df_clean.astype(object).fillna('')
    header = df_clean.columns.tolist()
    data = df_clean.values.tolist()
    clean_data = []
    
    for row in data:
        clean_row = []
        for cell in row:
            # FIXED: Using proper datetime type checking
            if isinstance(cell, (datetime.datetime, pd.Timestamp)):
                clean_row.append(cell.strftime('%Y-%m-%d'))
            elif isinstance(cell, datetime.time):
                clean_row.append(cell.strftime('%H:%M:%S'))
            elif pd.isna(cell):
                clean_row.append('')
            else:
                clean_row.append(cell)
        clean_data.append(clean_row)
        
    values_with_header = [header] + clean_data
    try:
        service = build('sheets', 'v4', credentials=creds)
        service.spreadsheets().values().clear(spreadsheetId=spreadsheetId, range=spread_range, body={}).execute()
        body = {'values': values_with_header}
        result = service.spreadsheets().values().update(
            spreadsheetId=spreadsheetId, range=spread_range, valueInputOption="USER_ENTERED", body=body).execute()
        print(f"{result.get('updatedCells')} cells updated (sheet replaced).")
        return result
    except HttpError as error:
        print(f"An error occurred: {error}")
        return error

def find_cutoff_column(df, target_phrase="38 total spending  gr  sa"):
    for idx, col in enumerate(df.columns):
        if target_phrase.lower() in str(col).lower():
            return col, idx
    return None, None

def find_header_start_row(path, sheet_name, target_text="1 Tahun Capex"):
    # Read more rows (up to 20) to ensure we don't miss it
    df_raw = pd.read_excel(path, sheet_name=sheet_name, header=None, nrows=20)
    
    # Normalize target text: lowercase, remove dots, strip spaces
    cleaned_target = target_text.lower().replace('.', '').replace(' ', '')
    
    for idx, row in df_raw.iterrows():
        # Clean the row data: convert to string, lowercase, remove dots and all spaces
        cleaned_row = row.astype(str).str.lower().str.replace('.', '', regex=False).str.replace(' ', '', regex=False)
        
        # Check if the cleaned target phrase exists anywhere in the normalized row
        if cleaned_row.str.contains(cleaned_target, regex=False, na=False).any():
            return idx
            
    return None

def extract_data():
    files_and_sheets = [
        (r"C:\Users\mochamad.ilmawan\OneDrive - semenindonesia.com\Renstra\Capex\1. SP.xlsx", "SUMMARY"),
        (r"C:\Users\mochamad.ilmawan\OneDrive - semenindonesia.com\Renstra\Capex\2. ghopo rev.xlsx", "Prognose Spending"),
        (r"C:\Users\mochamad.ilmawan\OneDrive - semenindonesia.com\Renstra\Capex\3. SG .xlsx", "SUMMARY"),
        (r"C:\Users\mochamad.ilmawan\OneDrive - semenindonesia.com\Renstra\Capex\4. SMBR.xlsx", "SMBR 2026 R1"),
        (r"C:\Users\mochamad.ilmawan\OneDrive - semenindonesia.com\Renstra\Capex\5. ST.xlsx", "4000"),
        (r"C:\Users\mochamad.ilmawan\OneDrive - semenindonesia.com\Renstra\Capex\6. SBI.xlsx", "SUMMARY")
    ]

    all_dfs = []
    sg_columns = None
    
    for path, sheet in files_and_sheets:
        if os.path.exists(path):
            file_name = os.path.basename(path)
            print(f"Processing: {file_name} (Sheet: {sheet})...")
            
            # 1. DYNAMICALLY DETECT THE HEADER ROW
            header_start_idx = find_header_start_row(path, sheet)
            if header_start_idx is not None:
                # Assuming standard 3-level headers starting from discovered index
                chosen_header = [header_start_idx, header_start_idx + 1, header_start_idx + 2]
                print(f"   -> Found header starting at row index {header_start_idx}")
            else:
                chosen_header = [2, 3, 4]
                print("   -> '1 Tahun Capex' not found. Defaulting to header rows [2,3,4]")
                
            df = pd.read_excel(path, sheet_name=sheet, header=chosen_header)
            
            cleaned_cols = []
            for col in df.columns:
                parts = []
                # Ensure we handle multi-index tuple gracefully
                levels = col if isinstance(col, tuple) else [col]
                for level in levels:
                    level_str = str(level).strip().lower()
                    if "unnamed:" not in level_str and level_str != "nan" and level_str != "":
                        if not parts or parts[-1] != level_str:
                            parts.append(level_str)
                col_name = "_".join(parts) if parts else "unnamed"
                cleaned_cols.append(col_name)

            final_cols = []
            col_counts = {}
            for col in cleaned_cols:
                col_clean = col.replace('/', '').replace('.', '')

                if col_clean.endswith('_a'):
                    col_clean = col_clean[:-2]
                if col_clean in col_counts:
                    col_counts[col_clean] += 1
                    final_cols.append(f"{col_clean}_{col_counts[col_clean]}")
                else:
                    col_counts[col_clean] = 0
                    final_cols.append(col_clean)

            
            df.columns = final_cols

            cutoff_col, cutoff_idx = find_cutoff_column(df)
            if cutoff_col:
                print(f"   -> Found target column '{cutoff_col}' at index {cutoff_idx}")
                df = df.iloc[:, :cutoff_idx + 1]
            else:
                print("   -> Target column not found. Keeping original dataframe structure.")
                df = df.copy()

            df = df.dropna(how='all')
            if "4 entitas" in df.columns:
                df = df[df["4 entitas"].notna() & (df["4 entitas"].astype(str).str.strip() != "")]
          
            if "15 % plan progres fisik (over all)" in df.columns:
                df["15 % plan progres fisik (over all)"] = pd.to_numeric(df["15 % plan progres fisik (over all)"], errors='coerce')
            
            df["Source_File"] = file_name
            if "5. ST" in file_name:
                print(df)
            # Capture the structure of sheet 3 ('3. SG .xlsx') to align structural variance
            if "3. SG" in file_name:
                sg_columns = list(df.columns)
            
            all_dfs.append(df)
        else:
            print(f"Error: File not found at {path}.")

    if all_dfs:
        combined_df = pd.concat(all_dfs, ignore_index=True)
        if sg_columns is not None:
            if "Source_File" not in sg_columns:
                sg_columns.append("Source_File")
            combined_df = combined_df.reindex(columns=sg_columns)
            print("\nSuccessfully aligned all data to the SG master framework!")
        else:
            print("\nWarning: '3. SG .xlsx' columns were not found. Data combined with default structure.")
        return combined_df
    return None

def main():
    combined_df = extract_data()
    if combined_df is not None:
        display(combined_df.head(10))
        print(f"Final Data Shape: {combined_df.shape[0]} rows x {combined_df.shape[1]} columns")
        creds = connect_to_sheet()
        update_sheet('1ckgGhsbbHGYfpqXtak_EG79ElY00bTvAADbNySRMa1s', 'Sheet1', None, creds, combined_df)

if __name__ == '__main__':
    main()
# Out:
# Processing: 1. SP.xlsx (Sheet: SUMMARY)...
#    -> Found header starting at row index 2
#    -> Found target column '38 total spending  gr  sa' at index 38
# Processing: 2. ghopo rev.xlsx (Sheet: Prognose Spending)...
#    -> Found header starting at row index 1
#    -> Found target column '38 total spending  gr  sa' at index 38
# Processing: 3. SG .xlsx (Sheet: SUMMARY)...
#    -> Found header starting at row index 2
#    -> Found target column '38 total spending  gr  sa_25360852999' at index 38
# Processing: 4. SMBR.xlsx (Sheet: SMBR 2026 R1)...
#    -> Found header starting at row index 2
#    -> Found target column '38 total spending  gr  sa' at index 38
# Processing: 5. ST.xlsx (Sheet: 4000)...
#    -> Found header starting at row index 4
#    -> Found target column '38 total spending  gr  sa_81780306626' at index 40
#         no  pic  1 tahun capex                              2 item capex  \
# 0      1.0  NaN         2026.0    ST-I REPLACE BEARING TURBIN GP SST-300
# 1      2.0  NaN         2026.0    ST-I ADDITIONAL RAW WATERTANK GP C03PP
# 2      3.0  NaN         2026.0      ST-4 REPLACE PART COOLER PKC 417CC01
# 3      4.0  NaN         2026.0  ST-4 REPLACE BUCKET ELEVATOR RPT 412BE01
# 4      5.0  NaN         2026.0    ST-4 REFURBISH KANTOR OHS GP STBUILD01
# ..     ...  ...            ...                                       ...
# 196  197.0  NaN         2024.0  ST-4 REPLACE A.SAMPLING FM 4 LSP 739ST02
# 199    NaN  NaN         2024.0      ST-P REPAIR JALAN POROS SFG PP SMRND
# 200  198.0  NaN         2022.0    ST-L DEVELOP JALAN TAMBANG RDS PACCOLA
# 201  199.0  NaN         2023.0  ST-5 ADDITIONAL PEMANFAATAN GAS PANAS CO
# 202  200.0  NaN         2024.0  DEVELOPMENT PLAN OPTIMIZER KILN TONASA 4
#
#     3 no project  wbs  4 entitas                            5 departemen  \
# 0            P2-26167     4000.0  Dept of Mining Operation & Power Plant
# 1            P2-26254     4000.0  Dept of Mining Operation & Power Plant
# 2            P2-26213     4000.0                    Dept. of Maintenance
# 3            P2-26211     4000.0                    Dept. of Maintenance
# 4            P2-26228     4000.0  Dept of Production Planning & Control
# ..                ...        ...                                     ...
# 196          P2-24351     4000.0  Dept. of Production Planning & Control
# 199          P2-24372     4000.0   Dept. SCM Infrastructure Management 2
# 200          P6-23444     4000.0           Dept. of Mining & Power Plant
# 201          P6-23507     4000.0    Dept. of Clinker & Cement Production
# 202          P6-24023     4000.0                    Dept. of Maintenance
#
#                               unit kerja 6 tipe capex 7 new  coc  multiyears  \
# 0      Unit of Power Plant Machine Maint           KO                    NEW
# 1          Unit of Power Plant Operation           KO                    NEW
# 2          Unit of Machine Maintenance 2           KO                    NEW
# 3          Unit of Machine Maintenance 2           KO                    NEW
# 4                            Unit of OHS          PKO                    NEW
# ..                                   ...          ...                    ...
# 196              Unit of Quality Control           KO             MULTIYEARS
# 199  Unit Port Operation & Maintenance 3           KO             MULTIYEARS
# 200                    Unit of Mine Plan          STR             MULTIYEARS
# 201            Unit of Cement Production          STR             MULTIYEARS
# 202         Unit of Elins Maintenance 2            PO             MULTIYEARS
#
#      ... 30 total nilai investasi rkap  31 total pr_new rekap 21-25  \
# 0    ...                  5.577715e+09                 0.000000e+00
# 1    ...                  5.000000e+09                 0.000000e+00
# 2    ...                  4.042504e+09                 0.000000e+00
# 3    ...                  3.784485e+09                 0.000000e+00
# 4    ...                  3.500000e+09                 0.000000e+00
# ..   ...                           ...                          ...
# 196  ...                  2.502000e+09                 2.502000e+09
# 199  ...                  7.403240e+08                 7.513057e+08
# 200  ...                  5.125399e+10                 1.544616e+09
# 201  ...                  1.997418e+10                 9.661309e+09
# 202  ...                  1.227500e+10                 9.713917e+09
#
#                                               32 no pr  \
# 0                                           6400000937
# 1                                                  NaN
# 2                                                  NaN
# 3                                           6400000916
# 4                                                  NaN
# ..                                                 ...
# 196                                         6400000750
# 199                                         6300001788
# 200                 6300001798\n6300001817\n4300017625
# 201                                         6300001769
# 202  6300001777\n6400000897\n6400000898\n6400000899...
#
#     33 total po_new rekap 21-25  \
# 0                  0.000000e+00
# 1                  0.000000e+00
# 2                  0.000000e+00
# 3                  0.000000e+00
# 4                  0.000000e+00
# ..                          ...
# 196                2.500000e+09
# 199                7.275930e+08
# 200                8.443413e+08
# 201                9.645000e+09
# 202                6.654657e+09
#
#                                               34 no po 35 pelampauan  \
# 0                                                  NaN     Tidak Ada
# 1                                                  NaN     Tidak Ada
# 2                                                  NaN     Tidak Ada
# 3                                                  NaN     Tidak Ada
# 4                                                  NaN     Tidak Ada
# ..                                                 ...           ...
# 196                                         8400002063     Tidak Ada
# 199                                         8400002157     Tidak Ada
# 200                             8400002168\n8400002223     Tidak Ada
# 201                                         8400002156     Tidak Ada
# 202  8400002161\n8400002226\n8400002225\n8400002229...     Tidak Ada
#
#     36 nilai pelampauan  37 spending  gr  sa tahun sebelumnya_59601607211  \
# 0                   0.0                                      0.000000e+00
# 1                   0.0                                      0.000000e+00
# 2                   0.0                                      0.000000e+00
# 3                   0.0                                      0.000000e+00
# 4                   0.0                                      0.000000e+00
# ..                  ...                                               ...
# 196                 0.0                                      0.000000e+00
# 199                 NaN                                      0.000000e+00
# 200                 NaN                                      2.307639e+10
# 201                 NaN                                      0.000000e+00
# 202                 NaN                                      0.000000e+00
#
#      38 total spending  gr  sa_81780306626 Source_File
# 0                             0.000000e+00  5. ST.xlsx
# 1                             0.000000e+00  5. ST.xlsx
# 2                             0.000000e+00  5. ST.xlsx
# 3                             0.000000e+00  5. ST.xlsx
# 4                             0.000000e+00  5. ST.xlsx
# ..                                     ...         ...
# 196                           2.500000e+09  5. ST.xlsx
# 199                           7.275930e+08  5. ST.xlsx
# 200                           2.312589e+10  5. ST.xlsx
# 201                           0.000000e+00  5. ST.xlsx
# 202                           0.000000e+00  5. ST.xlsx
#
# [201 rows x 42 columns]
# Processing: 6. SBI.xlsx (Sheet: SUMMARY)...
#    -> Found header starting at row index 2
#    -> Found target column '38 total spending  gr  sa' at index 38
#
# Successfully aligned all data to the SG master framework!
#    no 1 tahun capex                              2 item capex  \
# 0   1          2024               SP-T REPLACE UPS SS ERC 268
# 1   2          2024    SP-T REPLACE OH FEEDER SYSTE LC 6A1M01
# 2   3          2024       SP-T REPLACE CAPASITOR BANK ERC 218
# 3   4          2024             SP-T REPLACE OH RBC RH 6A1J07
# 4   5          2024           SP-T REPLACE OH RBC RH LS IND 6
# 5   6          2024       SP-T REPLACE OH RBC RH JALUR SILICA
# 6   7          2024  SP-T REPLACE OH RBC RH A1J12B,20103&2010
# 7   8          2024  SP-T REPLACE OH RBC  RH STORAGE LS IND 5
# 8   9          2024  SP-1 REPLACE KOMPRESSOR VACUUM  BP 1Q3M0
# 9  10          2023     SP-I REPLACE SUPRAREX P5000 WH 2CNC01
#
#   3 no project  wbs 4 entitas                         5 departemen  \
# 0  P2-24541-03-C-07      3000     TAMBANG & PENGELOLAAN BAHAN BAKU
# 1  P2-24236-03-C-07      3000     TAMBANG & PENGELOLAAN BAHAN BAKU
# 2  P2-24232-03-C-07      3000     TAMBANG & PENGELOLAAN BAHAN BAKU
# 3  P2-24227-03-C-07      3000     TAMBANG & PENGELOLAAN BAHAN BAKU
# 4  P2-24216-03-C-07      3000     TAMBANG & PENGELOLAAN BAHAN BAKU
# 5  P2-24215-03-C-07      3000     TAMBANG & PENGELOLAAN BAHAN BAKU
# 6  P2-24214-03-C-07      3000     TAMBANG & PENGELOLAAN BAHAN BAKU
# 7  P2-24211-03-C-07      3000     TAMBANG & PENGELOLAAN BAHAN BAKU
# 8  P2-24158-03-C-21      3000  INFRASTRUKTUR & INTERPLANT LOGISTIK
# 9  P2-23552-03-C-74      3000                                 BINS
#
#   6 tipe capex 7 new  coc  multiyears 8 ruang lingkup pengadaan  \
# 0           KO                    NaN                    BARANG
# 1           KO                    NaN                    BARANG
# 2           KO                    NaN                    BARANG
# 3           KO                    NaN             BARANG & JASA
# 4           KO                    NaN             BARANG & JASA
# 5           KO                    NaN             BARANG & JASA
# 6           KO                    NaN             BARANG & JASA
# 7           KO                    NaN             BARANG & JASA
# 8           KO                    NaN             BARANG & JASA
# 9          PKO                    NaN             BARANG & JASA
#
#    9 rencana jumlah pengadaan  ...  30 total nilai investasi rkap 31 total pr  \
# 0                         1.0  ...                   1.350000e+09  1350000000
# 1                         1.0  ...                   2.332969e+09  2018436792
# 2                         1.0  ...                   6.637180e+08   663718026
# 3                         2.0  ...                   2.943688e+09  2693446118
# 4                         6.0  ...                   2.101189e+09  2137748544
# 5                         4.0  ...                   2.977217e+09  2977216752
# 6                         4.0  ...                   2.941356e+09  2917200000
# 7                         4.0  ...                   2.707470e+09  2481389952
# 8                         2.0  ...                   7.449596e+08   744959575
# 9                         2.0  ...                   1.700000e+09  1600000000
#
#                                             32 no pr   33 total po  \
# 0                                         6200004130   943999998.0
# 1                             6200004142, 6200004183  1246260000.0
# 2                                         6200004179   643000000.0
# 3                             6200004162, 6200004159  2895000000.0
# 4  6200004141, 6200004140, 6200004253, 6200004144...  1616020000.0
# 5     6200004139, 6200004254, 6200004143, 6200004143  2959956800.0
# 6                 6200004391, 6200004251, 6200004136  2883400000.0
# 7                 6200004138, 6200004252, 6200004137  2464130000.0
# 8                             6200004133, 6200004133   696500000.0
# 9                                         6200004005  1595000000.0
#
#                                             34 no po  35 pelampauan  \
# 0                                         7400002967            NaN
# 1                             7400003177, 7400003179            NaN
# 2                                         7400002984            NaN
# 3                             7400002880, 7400003074            NaN
# 4  7400003025, 7400002972, 7400003028, 7400003109...            NaN
# 5     7400003025, 7400002904, 7400002853, 7400002855            NaN
# 6     7400003123, 7400002903, 7400002850, 7400003171            NaN
# 7                 7400003025, 7400002902, 7400002851            NaN
# 8                             7400003099, 7400003069            NaN
# 9                                         7400003127            NaN
#
#    36 nilai pelampauan 37 spending  gr  sa tahun sebelumnya  \
# 0                  NaN                         9.440000e+08
# 1                  NaN                         0.000000e+00
# 2                  NaN                         6.430000e+08
# 3                  NaN                         2.895000e+09
# 4                  NaN                         1.464470e+09
# 5                  NaN                         2.951957e+09
# 6                  NaN                         2.217900e+09
# 7                  NaN                         2.464130e+09
# 8                  NaN                         2.408950e+09
# 9                  NaN                         0.000000e+00
#
#   38 total spending  gr  sa_25360852999 Source_File
# 0                                   NaN  1. SP.xlsx
# 1                                   NaN  1. SP.xlsx
# 2                                   NaN  1. SP.xlsx
# 3                                   NaN  1. SP.xlsx
# 4                                   NaN  1. SP.xlsx
# 5                                   NaN  1. SP.xlsx
# 6                                   NaN  1. SP.xlsx
# 7                                   NaN  1. SP.xlsx
# 8                                   NaN  1. SP.xlsx
# 9                                   NaN  1. SP.xlsx
#
# [10 rows x 40 columns]
# Final Data Shape: 945 rows x 40 columns
# 37840 cells updated (sheet replaced).
